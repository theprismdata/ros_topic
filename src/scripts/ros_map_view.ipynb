# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from scipy.ndimage import rotate

# %%
# np.set_printoptions(threshold=np.inf)

# %%
map = cv2.imread('map.pgm')

# %%
map.shape
# Out:
# (384, 384, 3)

# %%
print(map)
# Out:
# [[[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]
#
#  [[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]
#
#  [[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]
#
#  ...
#
#  [[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]
#
#  [[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]
#
#  [[205 205 205]
#   [205 205 205]
#   [205 205 205]
#   ...
#   [205 205 205]
#   [205 205 205]
#   [205 205 205]]]

# %%
cv2.imshow('image', map)

# %%
plt.title('Original Map')
plt.imshow(map)

# %%
rotated_map = rotate(map, angle=15)
plt.title('Rotation 15 degree')
plt.imshow(rotated_map)
